# %%
from scripts.load_data import load_data

load_data([2015, 2018, 2021, 2024])
# Out:
#                Kod stacji  (Jelenia Góra, DsJelGorOgin)  \
# 0     2015-01-01 01:00:00                       151.112
# 1     2015-01-01 02:00:00                       262.566
# 2     2015-01-01 03:00:00                       222.830
# 3     2015-01-01 04:00:00                       210.767
# 4     2015-01-01 05:00:00                       191.211
# ...                   ...                           ...
# 35059 2024-12-31 20:00:00                        48.300
# 35060 2024-12-31 21:00:00                        67.000
# 35061 2024-12-31 22:00:00                        72.700
# 35062 2024-12-31 23:00:00                        79.900
# 35063 2024-12-31 23:55:00                        67.900
#
#        (Wrocław, DsWrocAlWisn)  (Wrocław, DsWrocWybCon)  \
# 0                         78.0                  50.0000
# 1                         42.0                  33.8244
# 2                         27.0                  28.7215
# 3                         24.0                  20.6891
# ...

# %%
import pandas
